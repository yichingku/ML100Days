# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0,180)
y = np.sin(x * np.pi / 180.0)

# %%
plt.plot(x,y)

# %%
plt.xlim(-30,390)plt.ylim(-1.5,1.5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/inputtransformer2.py:484: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")
#   File "<ipython-input-18-384b22ec1344>", line 1
#     plt.xlim(-30,390)
#
# ^
# SyntaxError: invalid character in identifier

# %%
plt.xlabel("x-axis") 
	plt.ylabel("y-axis") 
	plt.title("The Title")
# Out:
#   File "<ipython-input-19-8fa137724b8d>", line 2
#     plt.ylabel("y-axis")
#     ^
# IndentationError: unexpected indent

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

plt.scatter(X,Y)
plt.show()

# %%
t = np.arange(0., 10., 0.7)
print("t: "+str(t))

plt.plot(t, t, 'r--', t, t**2, 'bs', t**3, 'g^' )
# Out:
# t: [0.  0.7 1.4 2.1 2.8 3.5 4.2 4.9 5.6 6.3 7.  7.7 8.4 9.1 9.8]
# ...
